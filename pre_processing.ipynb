# %%
text = "Cars. Cars hav been around since they became famaus in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major rolle in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do."

# %% [markdown]
# ## I. Text Structure :
# ###     1.1 Spelling Errors

# %%
# import packages
import nltk
import pandas as pd 
import string

from spellchecker import SpellChecker
from nltk import pos_tag
from nltk.tokenize import word_tokenize


# Download the NLTK data for POS tagging
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Handy functions 
def remove_punctuation(text):
    """
      Removes punctuation from text
    """
    translator = str.maketrans("", "", string.punctuation)
    text_without_punctuations = text.translate(translator)

    return text_without_punctuations






def correct_spelling(text):
    spell = SpellChecker()
    spelling_errors_count = 0
    text = remove_punctuation(text)
    words = word_tokenize(text)
    
    corrected_words = [spell.correction(word.lower()) if spell.correction(word.lower()) is not None else word for word in words]
    # Counting the number of words that have been corrected
    for word in words: 
        if spell.correction(word.lower()) != word.lower():
            spelling_errors_count += 1
    
    corrected_text = ' '.join(corrected_words)
    spelling_errors_rate = spelling_errors_count/len(words)

    return corrected_text, spelling_errors_rate   # corrected_text is only to debug and check the output, we are interested in spelling_errors_count 

# Example usage


# Load dataset {test_tesxt.csv} I tried to generate a data set using CHATGBT, dataset consist of two columns {original_text, wrong_spelling}  pairs of origianl text and the same text with wrong spelling errors scatered in the text.
df = pd.read_csv('test_text.csv')



df['corrected_text'], df['spelling_errors_rate'] = zip(*df['wrong_spelling'].apply(correct_spelling))  #  using * to unpack the zip into the two columns.


## This is Only for testing the output and confirm the results
for i in range(len(df)):

    print( "original: ",df['original_text'][i])
    print("Wrong: ",df['wrong_spelling'][i])
    print("Corrected: ", df['corrected_text'][i])
    print("Spelling Errors Rate: ", df['spelling_errors_rate'][i])
    print('')
# Out:
# original:  The quick brown fox jumps over the lazy dog.
# Wrong:  The quick brown fox jumps over the lazy dog.
# Corrected:  the quick brown fox jumps over the lazy dog
# Spelling Errors Rate:  0.0
#
# original:  Test Test Test Test
# Wrong:   Test Test Test Test.
# Corrected:  test test test test
# Spelling Errors Rate:  0.0
#
# original:  The quick brown fox jumps over the lazy dog.
# Wrong:  The quik brown fox jumps ovr the lazy dog.
# Corrected:  the quit brown fox jumps or the lazy dog
# Spelling Errors Rate:  0.2222222222222222
#
# original:  Artificial intelligence is changing the world.
# Wrong:  Artifical inteligence is changing the world.
# Corrected:  artificial intelligence is changing the world
# Spelling Errors Rate:  0.3333333333333333
#
# original:  Programming languages are essential for software development.
# Wrong:  Programing languages are essntial for software developement.
# Corrected:  programing languages are essential for software development
# Spelling Errors Rate:  0.2857142857142857
#
# original:  Data analysis plays a crucial role in decision-making.
# Wrong:  Data anlysis plays a crucial role in decision-making.
# Corrected:  data analysis plays a crucial role in decisionmaking
# Spelling Errors Rate:  0.25
#
# original:  I love exploring new technologies and learning new things.
# Wrong:  I love explorng new tecnologies and learning new things.
# Corrected:  i love exploring new technologies and learning new things
# Spelling Errors Rate:  0.2222222222222222
#
# original:  The sun sets in the west.
# Wrong:  The son sets in the west.
# Corrected:  the son sets in the west
# Spelling Errors Rate:  0.0
#
# original:  Coding is a valuable skill.
# Wrong:  Codeing is a valuable skil.
# Corrected:  coding is a valuable skin
# Spelling Errors Rate:  0.4
#
# original:  Learning new things is always exciting.
# Wrong:  Learnig new thing is always excting.
# Corrected:  learning new thing is always exciting
# Spelling Errors Rate:  0.3333333333333333
#
# original:  Nature provides a sense of calm.
# Wrong:  Nauture provides a sence of calm.
# Corrected:  nature provides a since of calm
# Spelling Errors Rate:  0.3333333333333333
#
# original:  The internet connects people worldwide.
# Wrong:  The interent conects people worldwide.
# Corrected:  the interest connects people worldwide
# Spelling Errors Rate:  0.4
#
# original:  Coffee is a popular beverage.
# Wrong:  Coffe is a populer bevrage.
# Corrected:  coffe is a popular beverage
# Spelling Errors Rate:  0.4
#
# original:  Reading books broadens the mind.
# Wrong:  Reding books broaden the mind.
# Corrected:  reading books broaden the mind
# Spelling Errors Rate:  0.2
#
# original:  The sky is clear and blue.
# Wrong:  The skiy is clear and bleu.
# Corrected:  the skin is clear and bleu
# Spelling Errors Rate:  0.16666666666666666
#
# original:  Exercise is important for a healthy lifestyle.
# Wrong:  Exercize is importnt for a helthy lifestlye.
# Corrected:  exercise is important for a healthy lifestyle
# Spelling Errors Rate:  0.5714285714285714
#
# original:  The sun sets in the west, painting the sky with hues of orange and pink.
# Wrong:  The sun set in the west, paintng the sky with hues of oragne and pink.
# Corrected:  the sun set in the west painting the sky with hues of orange and pink
# Spelling Errors Rate:  0.13333333333333333
#
# original:  In the midst of winter, I found there was, within me, an invincible summer.
# Wrong:  In the midst of wnter, I found there was, within me, an invincble summer.
# Corrected:  in the midst of water i found there was within me an invincible summer
# Spelling Errors Rate:  0.14285714285714285
#
# original:  Success is not final, failure is not fatal: It is the courage to continue that counts.
# Wrong:  Sucess is not finl, failre is not fatel: It is the couage to contnue that counts.
# Corrected:  success is not find failure is not fate it is the courage to continue that counts
# Spelling Errors Rate:  0.375
#
# original:  The only limit to our realization of tomorrow will be our doubts of today.
# Wrong:  The only limit to our realzation of tomrrow will be our doubs of today.
# Corrected:  the only limit to our realization of tomorrow will be our doubt of today
# Spelling Errors Rate:  0.21428571428571427
#
# original:  Two roads diverged in a wood, and I—I took the one less traveled by.
# Wrong:  Two roads diverged in a wood, and I—I took the one less travled by.
# Corrected:  two roads diverged in a wood and ii took the one less traveled by
# Spelling Errors Rate:  0.14285714285714285
#
# original:  Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do.
# Wrong:  Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do.
# Corrected:  cars cars have been around since they became famous in the 1900s when henry ford created and built the first model cars have played a major role in our every day lives since then but now people are starting to question if limiting car usage would be a good thing to me limiting the use of cars might be a good thing to do
# Spelling Errors Rate:  0.03125
#
# original:  The second advantage that would come with limiting car use is less stress. Everyone knows that driving a car causes emence amounts of stress. Getting caught in traffic is a major cause of stress in someones life. having to repeating wash your car just to get it dirt again causes stress. Having people in the iack of your car screaming and yelling all while music is ilasting, causes stress. So oiviously driving causes stress. If we were to limit our car usage we would not ie as stressed as we usually are. There would ie no traffic, no car washes and no one screaming in a small confineded space. In the first article " In German Suiuri, life goes on without cars", iy Elisaieth Rosenthal, a citizen named humdrum Walter, states " When i had a car i was always tense. I'm much happier this way". So with out the stress of a car humdrum Walter is a looser and happier person, less stress equals happier person. In the third article, " Carfree dai is spinning into a iig hit in Bogota", iy Andrew Selsky, it states " It's a good opportunity to take away stress...". If we have the opportunity to take away stress, why not take it. It is a huge advantage in our lives to limit driving if it takes away stress. No one wants stress, no one needs stress, and if we have an opportunity to take some of the stress away, take that opportunity.
# Wrong:  The second advantage that would come with limiting car use is less stress. Everyone knows that driving a car causes emence amounts of stress. Getting caught in traffic is a major cause of stress in someones life. having to repeating wash your car just to get it dirt again causes stress. Having people in the iack of your car screaming and yelling all while music is ilasting, causes stress. So oiviously driving causes stress. If we were to limit our car usage we would not ie as stressed as we usually are. There would ie no traffic, no car washes and no one screaming in a small confineded space. In the first article " In German Suiuri, life goes on without cars", iy Elisaieth Rosenthal, a citizen named humdrum Walter, states " When i had a car i was always tense. I'm much happier this way". So with out the stress of a car humdrum Walter is a looser and happier person, less stress equals happier person. In the third article, " Carfree dai is spinning into a iig hit in Bogota", iy Andrew Selsky, it states " It's a good opportunity to take away stress...". If we have the opportunity to take away stress, why not take it. It is a huge advantage in our lives to limit driving if it takes away stress. No one wants stress, no one needs stress, and if we have an opportunity to take some of the stress away, take that opportunity.
#
# Corrected:  the second advantage that would come with limiting car use is less stress everyone knows that driving a car causes fence amounts of stress getting caught in traffic is a major cause of stress in someones life having to repeating wash your car just to get it dirt again causes stress having people in the back of your car screaming and yelling all while music is lasting causes stress so obviously driving causes stress if we were to limit our car usage we would not ie as stressed as we usually are there would ie no traffic no car washes and no one screaming in a small confined space in the first article in german suture life goes on without cars iy elisabeth Rosenthal a citizen named humdrum walter states when i had a car i was always tense im much happier this way so with out the stress of a car humdrum walter is a looser and happier person less stress equals happier person in the third article carefree dai is spinning into a big hit in bogota iy andrew pesky it states its a good opportunity to take away stress if we have the opportunity to take away stress why not take it it is a huge advantage in our lives to limit driving if it takes away stress no one wants stress no one needs stress and if we have an opportunity to take some of the stress away take that opportunity
# Spelling Errors Rate:  0.044897959183673466

# %%
# Final result of pre-processing of Spelling errors should look like this
# This block of code just to remove the columns that we don't need anymore ( were used just to visualise and debug) and re-arrange the columns
df['input_text'] = df['wrong_spelling'] 
del df['wrong_spelling']
del df['original_text']
df = df[['input_text', 'spelling_errors_rate']]
df
# Out:
#                                            input_text  spelling_errors_rate
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898

# %% [markdown]
# ### 2.1 POS Tagging

# %% [markdown]
# ###

# %%
def generate_pos_tags(text):
    """
        Generates POS tags for the given text 
    """
    text = remove_punctuation(text)
    words = word_tokenize(text)

    pos_tags = pos_tag(words)

    return pos_tags

# Counting the number of words in the input text
def count_words(text):
    """
        Counts the number of words in the given text
    """
    clean_text = remove_punctuation(text)
    words = word_tokenize(clean_text)

    #print(words)
    return len(words)





# frequency of each POS tag in the text
from collections import Counter

def calc_frequency_pos_tags(text):
    tags = generate_pos_tags(text)
    total_words = count_words(text)
    freq_pos_tags = Counter(tag for word, tag in tags)  # This here returns a dictionary with the count of each POS tag in the text
    freq_pos_tags_dict = dict(freq_pos_tags) # Convert the Counter object to a dictionary
    for key, value in freq_pos_tags_dict.items(): # Calculate the frequency of each POS tag
        freq_pos_tags_dict[key] = (value/total_words)*100  # if we do round ()  total frequency will be under or over 100% due to rounding errors

    return freq_pos_tags_dict


# test on dataset

#df['POS tags'] = df['input_text'].apply(lambda x: generate_pos_tags(x)) # I left this until we decide if we need it or not because i have q question about it, => Should we do a list of tuples of POS  tags of sentences instead of individual words? like this [("DT","JJ","NN"),("D","N","V")] ???  because we have N-grams later which i guess holds more meaning than this.

df['POS tags Frequency'] = df['input_text'].apply(lambda x: calc_frequency_pos_tags(x))
df





### This to text on initial text it is defined in the begining of this file, it was used as initial testing text.
print(" frequency of each POS tag in the text:", calc_frequency_pos_tags(text))

df['Total frequency'] = df['POS tags Frequency'].apply(lambda x: sum(x.values())) # This is just to test if we have loss of frequency, it should be 100% for each row


df
# Out:
#  frequency of each POS tag in the text: {'NNS': 4.6875, 'NNP': 7.8125, 'VBD': 6.25, 'VBN': 3.125, 'IN': 10.9375, 'PRP': 3.125, 'NN': 12.5, 'DT': 10.9375, 'CD': 1.5625, 'WRB': 1.5625, 'CC': 3.125, 'JJ': 7.8125, 'VBP': 3.125, 'PRP$': 1.5625, 'VBZ': 1.5625, 'RB': 3.125, 'VBG': 3.125, 'TO': 4.6875, 'VB': 6.25, 'MD': 3.125}
#                                            input_text  spelling_errors_rate  \
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898
#
#                                    POS tags Frequency  Total frequency
# 0   {'DT': 22.22222222222222, 'JJ': 22.22222222222...            100.0
# 1                           {'NNP': 75.0, 'NN': 25.0}            100.0
# 2   {'DT': 22.22222222222222, 'JJ': 22.22222222222...            100.0
# 3   {'JJ': 16.666666666666664, 'NN': 33.3333333333...            100.0
# 4   {'VBG': 14.285714285714285, 'NNS': 14.28571428...            100.0
# 5   {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 1...            100.0
# 6   {'PRP': 11.11111111111111, 'VBP': 11.111111111...            100.0
# 7   {'DT': 33.33333333333333, 'NN': 33.33333333333...            100.0
# 8   {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 2...            100.0
# 9   {'NNP': 16.666666666666664, 'JJ': 16.666666666...            100.0
# 10  {'NNP': 16.666666666666664, 'VBZ': 16.66666666...            100.0
# 11  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 2...            100.0
# 12  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 4...            100.0
# 13  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 2...            100.0
# 14  {'DT': 16.666666666666664, 'NN': 33.3333333333...            100.0
# 15  {'NNP': 14.285714285714285, 'VBZ': 14.28571428...            100.0
# 16  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20...            100.0
# 17  {'IN': 21.428571428571427, 'DT': 14.2857142857...            100.0
# 18  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': ...            100.0
# 19  {'DT': 7.142857142857142, 'JJ': 7.142857142857...            100.0
# 20  {'CD': 7.142857142857142, 'NNS': 7.14285714285...            100.0
# 21  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN...            100.0
# 22  {'DT': 10.612244897959183, 'JJ': 7.34693877551...            100.0

# %%
# Droping the columns that we don't need anymore ['Total frequency']
del df['Total frequency']

# %% [markdown]
# ### 2.1.1 N-grams

# %%
from nltk import ngrams

def generate_ngrams_pos(tokens, n):
    """
        Generates n-grams with POS tags for the given tokens
    """
    text = remove_punctuation(tokens)
    words = word_tokenize(text)
    pos_tags = pos_tag(words)
    ngrams_result = list(ngrams(words, n))
   
    
    # Combine n-grams and POS tags
    ngrams_result = [(pos_tags[i][1], pos_tags[i+1][1]) for i in range(len(pos_tags)-1)]
    
    return ngrams_result


# test on dataset
df['2-grams'] = df['input_text'].apply(lambda x: generate_ngrams_pos(x, 2))

# To see results clearly 
for i in range(len(df)):

 
    print("Input_text: ",df['input_text'][i])
    print("Spelling Errors Rate: ", df['spelling_errors_rate'][i])
    print('')   
    print("POS tags Frequency: ", df['POS tags Frequency'][i])

    print("2-grams: ", df['2-grams'][i])

df
# Out:
# Input_text:  The quick brown fox jumps over the lazy dog.
# Spelling Errors Rate:  0.0
#
# POS tags Frequency:  {'DT': 22.22222222222222, 'JJ': 22.22222222222222, 'NN': 33.33333333333333, 'VBZ': 11.11111111111111, 'IN': 11.11111111111111}
# 2-grams:  [('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'NN'), ('NN', 'VBZ'), ('VBZ', 'IN'), ('IN', 'DT'), ('DT', 'JJ'), ('JJ', 'NN')]
# Input_text:   Test Test Test Test.
# Spelling Errors Rate:  0.0
#
# POS tags Frequency:  {'NNP': 75.0, 'NN': 25.0}
# 2-grams:  [('NNP', 'NNP'), ('NNP', 'NNP'), ('NNP', 'NN')]
# Input_text:  The quik brown fox jumps ovr the lazy dog.
# Spelling Errors Rate:  0.2222222222222222
#
# POS tags Frequency:  {'DT': 22.22222222222222, 'JJ': 22.22222222222222, 'NN': 33.33333333333333, 'NNS': 11.11111111111111, 'VBP': 11.11111111111111}
# 2-grams:  [('DT', 'JJ'), ('JJ', 'JJ'), ('JJ', 'NN'), ('NN', 'NNS'), ('NNS', 'VBP'), ('VBP', 'DT'), ('DT', 'NN'), ('NN', 'NN')]
# Input_text:  Artifical inteligence is changing the world.
# Spelling Errors Rate:  0.3333333333333333
#
# POS tags Frequency:  {'JJ': 16.666666666666664, 'NN': 33.33333333333333, 'VBZ': 16.666666666666664, 'VBG': 16.666666666666664, 'DT': 16.666666666666664}
# 2-grams:  [('JJ', 'NN'), ('NN', 'VBZ'), ('VBZ', 'VBG'), ('VBG', 'DT'), ('DT', 'NN')]
# Input_text:  Programing languages are essntial for software developement.
# Spelling Errors Rate:  0.2857142857142857
#
# POS tags Frequency:  {'VBG': 14.285714285714285, 'NNS': 14.285714285714285, 'VBP': 14.285714285714285, 'JJ': 14.285714285714285, 'IN': 14.285714285714285, 'NN': 28.57142857142857}
# 2-grams:  [('VBG', 'NNS'), ('NNS', 'VBP'), ('VBP', 'JJ'), ('JJ', 'IN'), ('IN', 'NN'), ('NN', 'NN')]
# Input_text:  Data anlysis plays a crucial role in decision-making.
# Spelling Errors Rate:  0.25
#
# POS tags Frequency:  {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 12.5, 'JJ': 12.5, 'IN': 12.5, 'VBG': 12.5}
# 2-grams:  [('NNP', 'NN'), ('NN', 'VBZ'), ('VBZ', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'VBG')]
# Input_text:  I love explorng new tecnologies and learning new things.
# Spelling Errors Rate:  0.2222222222222222
#
# POS tags Frequency:  {'PRP': 11.11111111111111, 'VBP': 11.11111111111111, 'RB': 11.11111111111111, 'JJ': 22.22222222222222, 'NNS': 22.22222222222222, 'CC': 11.11111111111111, 'VBG': 11.11111111111111}
# 2-grams:  [('PRP', 'VBP'), ('VBP', 'RB'), ('RB', 'JJ'), ('JJ', 'NNS'), ('NNS', 'CC'), ('CC', 'VBG'), ('VBG', 'JJ'), ('JJ', 'NNS')]
# Input_text:  The son sets in the west.
# Spelling Errors Rate:  0.0
#
# POS tags Frequency:  {'DT': 33.33333333333333, 'NN': 33.33333333333333, 'VBZ': 16.666666666666664, 'IN': 16.666666666666664}
# 2-grams:  [('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'IN'), ('IN', 'DT'), ('DT', 'NN')]
# Input_text:  Codeing is a valuable skil.
# Spelling Errors Rate:  0.4
#
# POS tags Frequency:  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 20.0, 'NN': 20.0}
# 2-grams:  [('NNP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'JJ'), ('JJ', 'NN')]
# Input_text:  Learnig new thing is always excting.
# Spelling Errors Rate:  0.3333333333333333
#
# POS tags Frequency:  {'NNP': 16.666666666666664, 'JJ': 16.666666666666664, 'NN': 16.666666666666664, 'VBZ': 16.666666666666664, 'RB': 16.666666666666664, 'VBG': 16.666666666666664}
# 2-grams:  [('NNP', 'JJ'), ('JJ', 'NN'), ('NN', 'VBZ'), ('VBZ', 'RB'), ('RB', 'VBG')]
# Input_text:  Nauture provides a sence of calm.
# Spelling Errors Rate:  0.3333333333333333
#
# POS tags Frequency:  {'NNP': 16.666666666666664, 'VBZ': 16.666666666666664, 'DT': 16.666666666666664, 'NN': 33.33333333333333, 'IN': 16.666666666666664}
# 2-grams:  [('NNP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'NN')]
# Input_text:  The interent conects people worldwide.
# Spelling Errors Rate:  0.4
#
# POS tags Frequency:  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 20.0}
# 2-grams:  [('DT', 'JJ'), ('JJ', 'NNS'), ('NNS', 'NNS'), ('NNS', 'VBP')]
# Input_text:  Coffe is a populer bevrage.
# Spelling Errors Rate:  0.4
#
# POS tags Frequency:  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 40.0}
# 2-grams:  [('NNP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'NN'), ('NN', 'NN')]
# Input_text:  Reding books broaden the mind.
# Spelling Errors Rate:  0.2
#
# POS tags Frequency:  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 20.0, 'NN': 20.0}
# 2-grams:  [('VBG', 'NNS'), ('NNS', 'IN'), ('IN', 'DT'), ('DT', 'NN')]
# Input_text:  The skiy is clear and bleu.
# Spelling Errors Rate:  0.16666666666666666
#
# POS tags Frequency:  {'DT': 16.666666666666664, 'NN': 33.33333333333333, 'VBZ': 16.666666666666664, 'JJ': 16.666666666666664, 'CC': 16.666666666666664}
# 2-grams:  [('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'JJ'), ('JJ', 'CC'), ('CC', 'NN')]
# Input_text:  Exercize is importnt for a helthy lifestlye.
# Spelling Errors Rate:  0.5714285714285714
#
# POS tags Frequency:  {'NNP': 14.285714285714285, 'VBZ': 14.285714285714285, 'VBN': 14.285714285714285, 'IN': 14.285714285714285, 'DT': 14.285714285714285, 'JJ': 14.285714285714285, 'NN': 14.285714285714285}
# 2-grams:  [('NNP', 'VBZ'), ('VBZ', 'VBN'), ('VBN', 'IN'), ('IN', 'DT'), ('DT', 'JJ'), ('JJ', 'NN')]
# Input_text:  The sun set in the west, paintng the sky with hues of oragne and pink.
# Spelling Errors Rate:  0.13333333333333333
#
# POS tags Frequency:  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20.0, 'VBZ': 6.666666666666667, 'NNS': 6.666666666666667, 'CC': 6.666666666666667, 'VB': 6.666666666666667}
# 2-grams:  [('DT', 'NN'), ('NN', 'NN'), ('NN', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'NNS'), ('NNS', 'IN'), ('IN', 'NN'), ('NN', 'CC'), ('CC', 'VB')]
# Input_text:  In the midst of wnter, I found there was, within me, an invincble summer.
# Spelling Errors Rate:  0.14285714285714285
#
# POS tags Frequency:  {'IN': 21.428571428571427, 'DT': 14.285714285714285, 'NN': 21.428571428571427, 'PRP': 14.285714285714285, 'VBD': 14.285714285714285, 'EX': 7.142857142857142, 'JJ': 7.142857142857142}
# 2-grams:  [('IN', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'NN'), ('NN', 'PRP'), ('PRP', 'VBD'), ('VBD', 'EX'), ('EX', 'VBD'), ('VBD', 'IN'), ('IN', 'PRP'), ('PRP', 'DT'), ('DT', 'JJ'), ('JJ', 'NN')]
# Input_text:  Sucess is not finl, failre is not fatel: It is the couage to contnue that counts.
# Spelling Errors Rate:  0.375
#
# POS tags Frequency:  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': 12.5, 'NN': 12.5, 'PRP': 6.25, 'DT': 12.5, 'TO': 6.25, 'VB': 6.25, 'NNS': 6.25}
# 2-grams:  [('NNP', 'VBZ'), ('VBZ', 'RB'), ('RB', 'JJ'), ('JJ', 'NN'), ('NN', 'VBZ'), ('VBZ', 'RB'), ('RB', 'JJ'), ('JJ', 'PRP'), ('PRP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'NN'), ('NN', 'TO'), ('TO', 'VB'), ('VB', 'DT'), ('DT', 'NNS')]
# Input_text:  The only limit to our realzation of tomrrow will be our doubs of today.
# Spelling Errors Rate:  0.21428571428571427
#
# POS tags Frequency:  {'DT': 7.142857142857142, 'JJ': 7.142857142857142, 'NN': 35.714285714285715, 'TO': 7.142857142857142, 'PRP$': 14.285714285714285, 'IN': 14.285714285714285, 'MD': 7.142857142857142, 'VB': 7.142857142857142}
# 2-grams:  [('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'TO'), ('TO', 'PRP$'), ('PRP$', 'NN'), ('NN', 'IN'), ('IN', 'NN'), ('NN', 'MD'), ('MD', 'VB'), ('VB', 'PRP$'), ('PRP$', 'NN'), ('NN', 'IN'), ('IN', 'NN')]
# Input_text:  Two roads diverged in a wood, and I—I took the one less travled by.
# Spelling Errors Rate:  0.14285714285714285
#
# POS tags Frequency:  {'CD': 7.142857142857142, 'NNS': 7.142857142857142, 'VBN': 14.285714285714285, 'IN': 14.285714285714285, 'DT': 14.285714285714285, 'NN': 14.285714285714285, 'CC': 7.142857142857142, 'NNP': 7.142857142857142, 'VBD': 7.142857142857142, 'JJR': 7.142857142857142}
# 2-grams:  [('CD', 'NNS'), ('NNS', 'VBN'), ('VBN', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'CC'), ('CC', 'NNP'), ('NNP', 'VBD'), ('VBD', 'DT'), ('DT', 'NN'), ('NN', 'JJR'), ('JJR', 'VBN'), ('VBN', 'IN')]
# Input_text:  Cars. Cars have been around since they became famous in the 1900s, when Henry Ford created and built the first ModelT. Cars have played a major role in our every day lives since then. But now, people are starting to question if limiting car usage would be a good thing. To me, limiting the use of cars might be a good thing to do.
# Spelling Errors Rate:  0.03125
#
# POS tags Frequency:  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN': 10.9375, 'PRP': 3.125, 'VBD': 4.6875, 'JJ': 9.375, 'DT': 10.9375, 'CD': 1.5625, 'WRB': 1.5625, 'NNP': 6.25, 'CC': 3.125, 'NN': 10.9375, 'PRP$': 1.5625, 'VBZ': 1.5625, 'RB': 3.125, 'VBG': 3.125, 'TO': 4.6875, 'VB': 6.25, 'MD': 3.125}
# 2-grams:  [('NNS', 'NNS'), ('NNS', 'VBP'), ('VBP', 'VBN'), ('VBN', 'IN'), ('IN', 'IN'), ('IN', 'PRP'), ('PRP', 'VBD'), ('VBD', 'JJ'), ('JJ', 'IN'), ('IN', 'DT'), ('DT', 'CD'), ('CD', 'WRB'), ('WRB', 'NNP'), ('NNP', 'NNP'), ('NNP', 'VBD'), ('VBD', 'CC'), ('CC', 'VBD'), ('VBD', 'DT'), ('DT', 'JJ'), ('JJ', 'NNP'), ('NNP', 'NNP'), ('NNP', 'VBP'), ('VBP', 'VBN'), ('VBN', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'PRP$'), ('PRP$', 'DT'), ('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'IN'), ('IN', 'RB'), ('RB', 'CC'), ('CC', 'RB'), ('RB', 'NNS'), ('NNS', 'VBP'), ('VBP', 'VBG'), ('VBG', 'TO'), ('TO', 'VB'), ('VB', 'IN'), ('IN', 'JJ'), ('JJ', 'NN'), ('NN', 'NN'), ('NN', 'MD'), ('MD', 'VB'), ('VB', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'TO'), ('TO', 'PRP'), ('PRP', 'VBG'), ('VBG', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'NNS'), ('NNS', 'MD'), ('MD', 'VB'), ('VB', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'TO'), ('TO', 'VB')]
# Input_text:  The second advantage that would come with limiting car use is less stress. Everyone knows that driving a car causes emence amounts of stress. Getting caught in traffic is a major cause of stress in someones life. having to repeating wash your car just to get it dirt again causes stress. Having people in the iack of your car screaming and yelling all while music is ilasting, causes stress. So oiviously driving causes stress. If we were to limit our car usage we would not ie as stressed as we usually are. There would ie no traffic, no car washes and no one screaming in a small confineded space. In the first article " In German Suiuri, life goes on without cars", iy Elisaieth Rosenthal, a citizen named humdrum Walter, states " When i had a car i was always tense. I'm much happier this way". So with out the stress of a car humdrum Walter is a looser and happier person, less stress equals happier person. In the third article, " Carfree dai is spinning into a iig hit in Bogota", iy Andrew Selsky, it states " It's a good opportunity to take away stress...". If we have the opportunity to take away stress, why not take it. It is a huge advantage in our lives to limit driving if it takes away stress. No one wants stress, no one needs stress, and if we have an opportunity to take some of the stress away, take that opportunity.
#
# Spelling Errors Rate:  0.044897959183673466
#
# POS tags Frequency:  {'DT': 10.612244897959183, 'JJ': 7.346938775510205, 'NN': 20.408163265306122, 'WDT': 0.40816326530612246, 'MD': 1.2244897959183674, 'VB': 4.8979591836734695, 'IN': 10.612244897959183, 'VBG': 4.489795918367347, 'VBZ': 6.122448979591836, 'RBR': 0.8163265306122449, 'NNS': 3.6734693877551026, 'VBN': 1.2244897959183674, 'TO': 2.857142857142857, 'PRP$': 2.0408163265306123, 'RB': 6.122448979591836, 'PRP': 4.081632653061225, 'CC': 1.6326530612244898, 'VBD': 1.2244897959183674, 'VBP': 2.0408163265306123, 'EX': 0.40816326530612246, 'CD': 0.40816326530612246, 'NNP': 4.489795918367347, 'WRB': 0.8163265306122449, 'RP': 1.2244897959183674, 'JJR': 0.8163265306122449}
# 2-grams:  [('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'WDT'), ('WDT', 'MD'), ('MD', 'VB'), ('VB', 'IN'), ('IN', 'VBG'), ('VBG', 'NN'), ('NN', 'NN'), ('NN', 'VBZ'), ('VBZ', 'RBR'), ('RBR', 'JJ'), ('JJ', 'NN'), ('NN', 'VBZ'), ('VBZ', 'IN'), ('IN', 'VBG'), ('VBG', 'DT'), ('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'NN'), ('NN', 'NNS'), ('NNS', 'IN'), ('IN', 'NN'), ('NN', 'VBG'), ('VBG', 'VBN'), ('VBN', 'IN'), ('IN', 'NN'), ('NN', 'VBZ'), ('VBZ', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'NN'), ('NN', 'IN'), ('IN', 'NNS'), ('NNS', 'NN'), ('NN', 'VBG'), ('VBG', 'TO'), ('TO', 'VBG'), ('VBG', 'VB'), ('VB', 'PRP$'), ('PRP$', 'NN'), ('NN', 'RB'), ('RB', 'TO'), ('TO', 'VB'), ('VB', 'PRP'), ('PRP', 'VB'), ('VB', 'RB'), ('RB', 'VBZ'), ('VBZ', 'JJ'), ('JJ', 'VBG'), ('VBG', 'NNS'), ('NNS', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'PRP$'), ('PRP$', 'NN'), ('NN', 'NN'), ('NN', 'CC'), ('CC', 'VBG'), ('VBG', 'DT'), ('DT', 'IN'), ('IN', 'NN'), ('NN', 'VBZ'), ('VBZ', 'VBG'), ('VBG', 'NNS'), ('NNS', 'RB'), ('RB', 'RB'), ('RB', 'RB'), ('RB', 'VBG'), ('VBG', 'NNS'), ('NNS', 'RB'), ('RB', 'IN'), ('IN', 'PRP'), ('PRP', 'VBD'), ('VBD', 'TO'), ('TO', 'VB'), ('VB', 'PRP$'), ('PRP$', 'NN'), ('NN', 'NN'), ('NN', 'PRP'), ('PRP', 'MD'), ('MD', 'RB'), ('RB', 'VB'), ('VB', 'RB'), ('RB', 'VBN'), ('VBN', 'IN'), ('IN', 'PRP'), ('PRP', 'RB'), ('RB', 'VBP'), ('VBP', 'EX'), ('EX', 'MD'), ('MD', 'VB'), ('VB', 'DT'), ('DT', 'NN'), ('NN', 'DT'), ('DT', 'NN'), ('NN', 'NNS'), ('NNS', 'CC'), ('CC', 'DT'), ('DT', 'CD'), ('CD', 'NN'), ('NN', 'IN'), ('IN', 'DT'), ('DT', 'JJ'), ('JJ', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'JJ'), ('JJ', 'NNP'), ('NNP', 'NN'), ('NN', 'VBZ'), ('VBZ', 'IN'), ('IN', 'IN'), ('IN', 'NNS'), ('NNS', 'JJ'), ('JJ', 'NNP'), ('NNP', 'NNP'), ('NNP', 'DT'), ('DT', 'NN'), ('NN', 'VBN'), ('VBN', 'NN'), ('NN', 'NNP'), ('NNP', 'VBZ'), ('VBZ', 'WRB'), ('WRB', 'NN'), ('NN', 'VBD'), ('VBD', 'DT'), ('DT', 'NN'), ('NN', 'NN'), ('NN', 'VBD'), ('VBD', 'RB'), ('RB', 'JJ'), ('JJ', 'NNP'), ('NNP', 'RB'), ('RB', 'RBR'), ('RBR', 'DT'), ('DT', 'NN'), ('NN', 'RB'), ('RB', 'IN'), ('IN', 'RP'), ('RP', 'DT'), ('DT', 'NN'), ('NN', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'NN'), ('NN', 'NNP'), ('NNP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'NN'), ('NN', 'CC'), ('CC', 'JJR'), ('JJR', 'NN'), ('NN', 'JJR'), ('JJR', 'JJ'), ('JJ', 'NNS'), ('NNS', 'VBP'), ('VBP', 'NN'), ('NN', 'IN'), ('IN', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'NNP'), ('NNP', 'NN'), ('NN', 'VBZ'), ('VBZ', 'VBG'), ('VBG', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'NN'), ('NN', 'IN'), ('IN', 'NNP'), ('NNP', 'NN'), ('NN', 'NNP'), ('NNP', 'NNP'), ('NNP', 'PRP'), ('PRP', 'VBZ'), ('VBZ', 'PRP$'), ('PRP$', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'TO'), ('TO', 'VB'), ('VB', 'RP'), ('RP', 'JJ'), ('JJ', 'IN'), ('IN', 'PRP'), ('PRP', 'VBP'), ('VBP', 'DT'), ('DT', 'NN'), ('NN', 'TO'), ('TO', 'VB'), ('VB', 'RP'), ('RP', 'JJ'), ('JJ', 'WRB'), ('WRB', 'RB'), ('RB', 'VB'), ('VB', 'PRP'), ('PRP', 'PRP'), ('PRP', 'VBZ'), ('VBZ', 'DT'), ('DT', 'JJ'), ('JJ', 'NN'), ('NN', 'IN'), ('IN', 'PRP$'), ('PRP$', 'NNS'), ('NNS', 'TO'), ('TO', 'VB'), ('VB', 'VBG'), ('VBG', 'IN'), ('IN', 'PRP'), ('PRP', 'VBZ'), ('VBZ', 'RB'), ('RB', 'JJ'), ('JJ', 'NNP'), ('NNP', 'NN'), ('NN', 'VBZ'), ('VBZ', 'JJ'), ('JJ', 'DT'), ('DT', 'NN'), ('NN', 'VBZ'), ('VBZ', 'NN'), ('NN', 'CC'), ('CC', 'IN'), ('IN', 'PRP'), ('PRP', 'VBP'), ('VBP', 'DT'), ('DT', 'NN'), ('NN', 'TO'), ('TO', 'VB'), ('VB', 'DT'), ('DT', 'IN'), ('IN', 'DT'), ('DT', 'NN'), ('NN', 'RB'), ('RB', 'VBP'), ('VBP', 'DT'), ('DT', 'NN')]
#                                            input_text  spelling_errors_rate  \
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898
#
#                                    POS tags Frequency  \
# 0   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 1                           {'NNP': 75.0, 'NN': 25.0}
# 2   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 3   {'JJ': 16.666666666666664, 'NN': 33.3333333333...
# 4   {'VBG': 14.285714285714285, 'NNS': 14.28571428...
# 5   {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 1...
# 6   {'PRP': 11.11111111111111, 'VBP': 11.111111111...
# 7   {'DT': 33.33333333333333, 'NN': 33.33333333333...
# 8   {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 2...
# 9   {'NNP': 16.666666666666664, 'JJ': 16.666666666...
# 10  {'NNP': 16.666666666666664, 'VBZ': 16.66666666...
# 11  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 2...
# 12  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 4...
# 13  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 2...
# 14  {'DT': 16.666666666666664, 'NN': 33.3333333333...
# 15  {'NNP': 14.285714285714285, 'VBZ': 14.28571428...
# 16  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20...
# 17  {'IN': 21.428571428571427, 'DT': 14.2857142857...
# 18  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': ...
# 19  {'DT': 7.142857142857142, 'JJ': 7.142857142857...
# 20  {'CD': 7.142857142857142, 'NNS': 7.14285714285...
# 21  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN...
# 22  {'DT': 10.612244897959183, 'JJ': 7.34693877551...
#
#                                               2-grams
# 0   [(DT, JJ), (JJ, NN), (NN, NN), (NN, VBZ), (VBZ...
# 1                 [(NNP, NNP), (NNP, NNP), (NNP, NN)]
# 2   [(DT, JJ), (JJ, JJ), (JJ, NN), (NN, NNS), (NNS...
# 3   [(JJ, NN), (NN, VBZ), (VBZ, VBG), (VBG, DT), (...
# 4   [(VBG, NNS), (NNS, VBP), (VBP, JJ), (JJ, IN), ...
# 5   [(NNP, NN), (NN, VBZ), (VBZ, DT), (DT, JJ), (J...
# 6   [(PRP, VBP), (VBP, RB), (RB, JJ), (JJ, NNS), (...
# 7   [(DT, NN), (NN, VBZ), (VBZ, IN), (IN, DT), (DT...
# 8         [(NNP, VBZ), (VBZ, DT), (DT, JJ), (JJ, NN)]
# 9   [(NNP, JJ), (JJ, NN), (NN, VBZ), (VBZ, RB), (R...
# 10  [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, IN), (I...
# 11      [(DT, JJ), (JJ, NNS), (NNS, NNS), (NNS, VBP)]
# 12        [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, NN)]
# 13        [(VBG, NNS), (NNS, IN), (IN, DT), (DT, NN)]
# 14  [(DT, NN), (NN, VBZ), (VBZ, JJ), (JJ, CC), (CC...
# 15  [(NNP, VBZ), (VBZ, VBN), (VBN, IN), (IN, DT), ...
# 16  [(DT, NN), (NN, NN), (NN, IN), (IN, DT), (DT, ...
# 17  [(IN, DT), (DT, NN), (NN, IN), (IN, NN), (NN, ...
# 18  [(NNP, VBZ), (VBZ, RB), (RB, JJ), (JJ, NN), (N...
# 19  [(DT, JJ), (JJ, NN), (NN, TO), (TO, PRP$), (PR...
# 20  [(CD, NNS), (NNS, VBN), (VBN, IN), (IN, DT), (...
# 21  [(NNS, NNS), (NNS, VBP), (VBP, VBN), (VBN, IN)...
# 22  [(DT, JJ), (JJ, NN), (NN, WDT), (WDT, MD), (MD...

# %%
# Calculate the frequency of each n-gram with POS tags

def calc_frequency_ngrams(tokens, n):
    ngrams = generate_ngrams_pos(tokens, n)
    total_ngrams = len(ngrams)
    freq_pos_tags = Counter(ngram for ngram in ngrams)  # This here returns a dictionary with the count of each POS tag in the text
    freq_ngrams_dict = dict(freq_pos_tags) # Convert the Counter object to a dictionary
    for key, value in freq_ngrams_dict.items(): # Calculate the frequency of each POS tag
        freq_ngrams_dict[key] = (value/total_ngrams)*100  # if we do round ()  total frequency will be under or over 100% due to rounding errors

    return freq_ngrams_dict



# test on dataset
df['2-grams frequency'] = df['input_text'].apply(lambda x: calc_frequency_ngrams(x, 2))
df['ngrams_frequency_total'] = df['2-grams frequency'].apply(lambda x: sum(x.values())) # This is just to test if we have loss of frequency, it should be 100% for each row


df
# Out:
#                                            input_text  spelling_errors_rate  \
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898
#
#                                    POS tags Frequency  \
# 0   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 1                           {'NNP': 75.0, 'NN': 25.0}
# 2   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 3   {'JJ': 16.666666666666664, 'NN': 33.3333333333...
# 4   {'VBG': 14.285714285714285, 'NNS': 14.28571428...
# 5   {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 1...
# 6   {'PRP': 11.11111111111111, 'VBP': 11.111111111...
# 7   {'DT': 33.33333333333333, 'NN': 33.33333333333...
# 8   {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 2...
# 9   {'NNP': 16.666666666666664, 'JJ': 16.666666666...
# 10  {'NNP': 16.666666666666664, 'VBZ': 16.66666666...
# 11  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 2...
# 12  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 4...
# 13  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 2...
# 14  {'DT': 16.666666666666664, 'NN': 33.3333333333...
# 15  {'NNP': 14.285714285714285, 'VBZ': 14.28571428...
# 16  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20...
# 17  {'IN': 21.428571428571427, 'DT': 14.2857142857...
# 18  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': ...
# 19  {'DT': 7.142857142857142, 'JJ': 7.142857142857...
# 20  {'CD': 7.142857142857142, 'NNS': 7.14285714285...
# 21  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN...
# 22  {'DT': 10.612244897959183, 'JJ': 7.34693877551...
#
#                                               2-grams  \
# 0   [(DT, JJ), (JJ, NN), (NN, NN), (NN, VBZ), (VBZ...
# 1                 [(NNP, NNP), (NNP, NNP), (NNP, NN)]
# 2   [(DT, JJ), (JJ, JJ), (JJ, NN), (NN, NNS), (NNS...
# 3   [(JJ, NN), (NN, VBZ), (VBZ, VBG), (VBG, DT), (...
# 4   [(VBG, NNS), (NNS, VBP), (VBP, JJ), (JJ, IN), ...
# 5   [(NNP, NN), (NN, VBZ), (VBZ, DT), (DT, JJ), (J...
# 6   [(PRP, VBP), (VBP, RB), (RB, JJ), (JJ, NNS), (...
# 7   [(DT, NN), (NN, VBZ), (VBZ, IN), (IN, DT), (DT...
# 8         [(NNP, VBZ), (VBZ, DT), (DT, JJ), (JJ, NN)]
# 9   [(NNP, JJ), (JJ, NN), (NN, VBZ), (VBZ, RB), (R...
# 10  [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, IN), (I...
# 11      [(DT, JJ), (JJ, NNS), (NNS, NNS), (NNS, VBP)]
# 12        [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, NN)]
# 13        [(VBG, NNS), (NNS, IN), (IN, DT), (DT, NN)]
# 14  [(DT, NN), (NN, VBZ), (VBZ, JJ), (JJ, CC), (CC...
# 15  [(NNP, VBZ), (VBZ, VBN), (VBN, IN), (IN, DT), ...
# 16  [(DT, NN), (NN, NN), (NN, IN), (IN, DT), (DT, ...
# 17  [(IN, DT), (DT, NN), (NN, IN), (IN, NN), (NN, ...
# 18  [(NNP, VBZ), (VBZ, RB), (RB, JJ), (JJ, NN), (N...
# 19  [(DT, JJ), (JJ, NN), (NN, TO), (TO, PRP$), (PR...
# 20  [(CD, NNS), (NNS, VBN), (VBN, IN), (IN, DT), (...
# 21  [(NNS, NNS), (NNS, VBP), (VBP, VBN), (VBN, IN)...
# 22  [(DT, JJ), (JJ, NN), (NN, WDT), (WDT, MD), (MD...
#
#                                     2-grams frequency  ngrams_frequency_total
# 0   {('DT', 'JJ'): 25.0, ('JJ', 'NN'): 25.0, ('NN'...                   100.0
# 1   {('NNP', 'NNP'): 66.66666666666666, ('NNP', 'N...                   100.0
# 2   {('DT', 'JJ'): 12.5, ('JJ', 'JJ'): 12.5, ('JJ'...                   100.0
# 3   {('JJ', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...                   100.0
# 4   {('VBG', 'NNS'): 16.666666666666664, ('NNS', '...                   100.0
# 5   {('NNP', 'NN'): 14.285714285714285, ('NN', 'VB...                   100.0
# 6   {('PRP', 'VBP'): 12.5, ('VBP', 'RB'): 12.5, ('...                   100.0
# 7   {('DT', 'NN'): 40.0, ('NN', 'VBZ'): 20.0, ('VB...                   100.0
# 8   {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...                   100.0
# 9   {('NNP', 'JJ'): 20.0, ('JJ', 'NN'): 20.0, ('NN...                   100.0
# 10  {('NNP', 'VBZ'): 20.0, ('VBZ', 'DT'): 20.0, ('...                   100.0
# 11  {('DT', 'JJ'): 25.0, ('JJ', 'NNS'): 25.0, ('NN...                   100.0
# 12  {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...                   100.0
# 13  {('VBG', 'NNS'): 25.0, ('NNS', 'IN'): 25.0, ('...                   100.0
# 14  {('DT', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...                   100.0
# 15  {('NNP', 'VBZ'): 16.666666666666664, ('VBZ', '...                   100.0
# 16  {('DT', 'NN'): 21.428571428571427, ('NN', 'NN'...                   100.0
# 17  {('IN', 'DT'): 7.6923076923076925, ('DT', 'NN'...                   100.0
# 18  {('NNP', 'VBZ'): 6.666666666666667, ('VBZ', 'R...                   100.0
# 19  {('DT', 'JJ'): 7.6923076923076925, ('JJ', 'NN'...                   100.0
# 20  {('CD', 'NNS'): 7.6923076923076925, ('NNS', 'V...                   100.0
# 21  {('NNS', 'NNS'): 1.5873015873015872, ('NNS', '...                   100.0
# 22  {('DT', 'JJ'): 2.8688524590163933, ('JJ', 'NN'...                   100.0

# %%
# Droping the columns that we don't need anymore ['ngrams_frequency_total']
del df['ngrams_frequency_total']
df
# Out:
#                                            input_text  spelling_errors_rate  \
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898
#
#                                    POS tags Frequency  \
# 0   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 1                           {'NNP': 75.0, 'NN': 25.0}
# 2   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 3   {'JJ': 16.666666666666664, 'NN': 33.3333333333...
# 4   {'VBG': 14.285714285714285, 'NNS': 14.28571428...
# 5   {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 1...
# 6   {'PRP': 11.11111111111111, 'VBP': 11.111111111...
# 7   {'DT': 33.33333333333333, 'NN': 33.33333333333...
# 8   {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 2...
# 9   {'NNP': 16.666666666666664, 'JJ': 16.666666666...
# 10  {'NNP': 16.666666666666664, 'VBZ': 16.66666666...
# 11  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 2...
# 12  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 4...
# 13  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 2...
# 14  {'DT': 16.666666666666664, 'NN': 33.3333333333...
# 15  {'NNP': 14.285714285714285, 'VBZ': 14.28571428...
# 16  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20...
# 17  {'IN': 21.428571428571427, 'DT': 14.2857142857...
# 18  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': ...
# 19  {'DT': 7.142857142857142, 'JJ': 7.142857142857...
# 20  {'CD': 7.142857142857142, 'NNS': 7.14285714285...
# 21  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN...
# 22  {'DT': 10.612244897959183, 'JJ': 7.34693877551...
#
#                                               2-grams  \
# 0   [(DT, JJ), (JJ, NN), (NN, NN), (NN, VBZ), (VBZ...
# 1                 [(NNP, NNP), (NNP, NNP), (NNP, NN)]
# 2   [(DT, JJ), (JJ, JJ), (JJ, NN), (NN, NNS), (NNS...
# 3   [(JJ, NN), (NN, VBZ), (VBZ, VBG), (VBG, DT), (...
# 4   [(VBG, NNS), (NNS, VBP), (VBP, JJ), (JJ, IN), ...
# 5   [(NNP, NN), (NN, VBZ), (VBZ, DT), (DT, JJ), (J...
# 6   [(PRP, VBP), (VBP, RB), (RB, JJ), (JJ, NNS), (...
# 7   [(DT, NN), (NN, VBZ), (VBZ, IN), (IN, DT), (DT...
# 8         [(NNP, VBZ), (VBZ, DT), (DT, JJ), (JJ, NN)]
# 9   [(NNP, JJ), (JJ, NN), (NN, VBZ), (VBZ, RB), (R...
# 10  [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, IN), (I...
# 11      [(DT, JJ), (JJ, NNS), (NNS, NNS), (NNS, VBP)]
# 12        [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, NN)]
# 13        [(VBG, NNS), (NNS, IN), (IN, DT), (DT, NN)]
# 14  [(DT, NN), (NN, VBZ), (VBZ, JJ), (JJ, CC), (CC...
# 15  [(NNP, VBZ), (VBZ, VBN), (VBN, IN), (IN, DT), ...
# 16  [(DT, NN), (NN, NN), (NN, IN), (IN, DT), (DT, ...
# 17  [(IN, DT), (DT, NN), (NN, IN), (IN, NN), (NN, ...
# 18  [(NNP, VBZ), (VBZ, RB), (RB, JJ), (JJ, NN), (N...
# 19  [(DT, JJ), (JJ, NN), (NN, TO), (TO, PRP$), (PR...
# 20  [(CD, NNS), (NNS, VBN), (VBN, IN), (IN, DT), (...
# 21  [(NNS, NNS), (NNS, VBP), (VBP, VBN), (VBN, IN)...
# 22  [(DT, JJ), (JJ, NN), (NN, WDT), (WDT, MD), (MD...
#
#                                     2-grams frequency
# 0   {('DT', 'JJ'): 25.0, ('JJ', 'NN'): 25.0, ('NN'...
# 1   {('NNP', 'NNP'): 66.66666666666666, ('NNP', 'N...
# 2   {('DT', 'JJ'): 12.5, ('JJ', 'JJ'): 12.5, ('JJ'...
# 3   {('JJ', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...
# 4   {('VBG', 'NNS'): 16.666666666666664, ('NNS', '...
# 5   {('NNP', 'NN'): 14.285714285714285, ('NN', 'VB...
# 6   {('PRP', 'VBP'): 12.5, ('VBP', 'RB'): 12.5, ('...
# 7   {('DT', 'NN'): 40.0, ('NN', 'VBZ'): 20.0, ('VB...
# 8   {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...
# 9   {('NNP', 'JJ'): 20.0, ('JJ', 'NN'): 20.0, ('NN...
# 10  {('NNP', 'VBZ'): 20.0, ('VBZ', 'DT'): 20.0, ('...
# 11  {('DT', 'JJ'): 25.0, ('JJ', 'NNS'): 25.0, ('NN...
# 12  {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...
# 13  {('VBG', 'NNS'): 25.0, ('NNS', 'IN'): 25.0, ('...
# 14  {('DT', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...
# 15  {('NNP', 'VBZ'): 16.666666666666664, ('VBZ', '...
# 16  {('DT', 'NN'): 21.428571428571427, ('NN', 'NN'...
# 17  {('IN', 'DT'): 7.6923076923076925, ('DT', 'NN'...
# 18  {('NNP', 'VBZ'): 6.666666666666667, ('VBZ', 'R...
# 19  {('DT', 'JJ'): 7.6923076923076925, ('JJ', 'NN'...
# 20  {('CD', 'NNS'): 7.6923076923076925, ('NNS', 'V...
# 21  {('NNS', 'NNS'): 1.5873015873015872, ('NNS', '...
# 22  {('DT', 'JJ'): 2.8688524590163933, ('JJ', 'NN'...

# %% [markdown]
# ## 2.c. Length of phrases

# %%
def analyze_length_text(text):
    """
        Analyzes the length of the given text
        -Take punctuations into account when calculating the length
    """

    phrases = nltk.sent_tokenize(text)
    phrases = [phrase.strip() for phrase in phrases if phrase.strip() ]
    phrases_lengths = [len(phrase) for phrase in phrases]

    lengths = [len(phrase) for phrase in phrases]
    max_length = max(lengths)
    min_length = min(lengths)
    avg_length = sum(lengths) / len(lengths)

    return phrases_lengths, max_length, min_length, avg_length

example_text = 'The second advantage that would come with limiting car use is less stress. Everyone knows that driving a car causes emence amounts of stress. Getting caught in traffic is a major cause of stress in someones life. having to repeating wash your car just to get it dirt again causes stress. Having people in the iack of your car screaming and yelling all while music is ilasting, causes stress. So oiviously driving causes stress. If we were to limit our car usage we would not ie as stressed as we usually are. There would ie no traffic, no car washes and no one screaming in a small confineded space. In the first article " In German Suiuri, life goes on without cars", iy Elisaieth Rosenthal, a citizen named humdrum Walter, states " When i had a car i was always tense. I\'m much happier this way". So with out the stress of a car humdrum Walter is a looser and happier person, less stress equals happier person. In the third article, " Carfree dai is spinning into a iig hit in Bogota", iy Andrew Selsky, it states " It\'s a good opportunity to take away stress...". If we have the opportunity to take away stress, why not take it. It is a huge advantage in our lives to limit driving if it takes away stress. No one wants stress, no one needs stress, and if we have an opportunity to take some of the stress away, take that opportunity.\r\n'
phrases_lengths, max_len, min_len, avg_len= analyze_length_text(example_text)

# Print the results
print(f"Maximum phrase length: {max_len} characters")
print(f"Minimum phrase length: {min_len} characters")
print(f"Average phrase length: {avg_len:.2f} characters")
print(f"Phrases lengths: {phrases_lengths}")


# apply on dataset
df['phrases_lengths'], df['phrase_max_length'], df['phrase_min_length'], df['phrase_avg_length'] = zip(*df['input_text'].apply(analyze_length_text))
# Out:
# Maximum phrase length: 170 characters
# Minimum phrase length: 27 characters
# Average phrase length: 88.20 characters
# Phrases lengths: [74, 66, 70, 74, 103, 35, 80, 90, 170, 27, 113, 153, 64, 77, 127]

# %%
df['input_text'].iloc[-1]
# Out:
# 'The second advantage that would come with limiting car use is less stress. Everyone knows that driving a car causes emence amounts of stress. Getting caught in traffic is a major cause of stress in someones life. having to repeating wash your car just to get it dirt again causes stress. Having people in the iack of your car screaming and yelling all while music is ilasting, causes stress. So oiviously driving causes stress. If we were to limit our car usage we would not ie as stressed as we usually are. There would ie no traffic, no car washes and no one screaming in a small confineded space. In the first article " In German Suiuri, life goes on without cars", iy Elisaieth Rosenthal, a citizen named humdrum Walter, states " When i had a car i was always tense. I\'m much happier this way". So with out the stress of a car humdrum Walter is a looser and happier person, less stress equals happier person. In the third article, " Carfree dai is spinning into a iig hit in Bogota", iy Andrew Selsky, it states " It\'s a good opportunity to take away stress...". If we have the opportunity to take away stress, why not take it. It is a huge advantage in our lives to limit driving if it takes away stress. No one wants stress, no one needs stress, and if we have an opportunity to take some of the stress away, take that opportunity.\r\n'

# %% [markdown]
# ## 2.d Vocabulary Richness

# %%
from math import sqrt

def calc_TTR(text):
    """
        Calculates the STTR of the given text (Type-Token Ratio)
    """

    tokens = word_tokenize(text.lower())
    types = len(set(tokens))
    tokens_count = len(tokens)
    TTR = types/tokens_count

    return TTR

def calculate_STTR(tokens):
    """
        Calculates the STTR of the given text ( Standarized Type-Token Ratio)
    """
    ttr = calc_TTR(tokens)
    sttr = ttr / sqrt(2 * len(tokens))
    return sttr


# test on dataset

df['STTR'] = df['input_text'].apply(lambda x: calculate_STTR(x))

df
# Out:
#                                            input_text  spelling_errors_rate  \
# 0        The quick brown fox jumps over the lazy dog.              0.000000
# 1                                Test Test Test Test.              0.000000
# 2          The quik brown fox jumps ovr the lazy dog.              0.222222
# 3        Artifical inteligence is changing the world.              0.333333
# 4   Programing languages are essntial for software...              0.285714
# 5   Data anlysis plays a crucial role in decision-...              0.250000
# 6   I love explorng new tecnologies and learning n...              0.222222
# 7                           The son sets in the west.              0.000000
# 8                         Codeing is a valuable skil.              0.400000
# 9                Learnig new thing is always excting.              0.333333
# 10                  Nauture provides a sence of calm.              0.333333
# 11             The interent conects people worldwide.              0.400000
# 12                        Coffe is a populer bevrage.              0.400000
# 13                     Reding books broaden the mind.              0.200000
# 14                        The skiy is clear and bleu.              0.166667
# 15       Exercize is importnt for a helthy lifestlye.              0.571429
# 16  The sun set in the west, paintng the sky with ...              0.133333
# 17  In the midst of wnter, I found there was, with...              0.142857
# 18  Sucess is not finl, failre is not fatel: It is...              0.375000
# 19  The only limit to our realzation of tomrrow wi...              0.214286
# 20  Two roads diverged in a wood, and I—I took the...              0.142857
# 21  Cars. Cars have been around since they became ...              0.031250
# 22  The second advantage that would come with limi...              0.044898
#
#                                    POS tags Frequency  \
# 0   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 1                           {'NNP': 75.0, 'NN': 25.0}
# 2   {'DT': 22.22222222222222, 'JJ': 22.22222222222...
# 3   {'JJ': 16.666666666666664, 'NN': 33.3333333333...
# 4   {'VBG': 14.285714285714285, 'NNS': 14.28571428...
# 5   {'NNP': 12.5, 'NN': 25.0, 'VBZ': 12.5, 'DT': 1...
# 6   {'PRP': 11.11111111111111, 'VBP': 11.111111111...
# 7   {'DT': 33.33333333333333, 'NN': 33.33333333333...
# 8   {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'JJ': 2...
# 9   {'NNP': 16.666666666666664, 'JJ': 16.666666666...
# 10  {'NNP': 16.666666666666664, 'VBZ': 16.66666666...
# 11  {'DT': 20.0, 'JJ': 20.0, 'NNS': 40.0, 'VBP': 2...
# 12  {'NNP': 20.0, 'VBZ': 20.0, 'DT': 20.0, 'NN': 4...
# 13  {'VBG': 20.0, 'NNS': 20.0, 'IN': 20.0, 'DT': 2...
# 14  {'DT': 16.666666666666664, 'NN': 33.3333333333...
# 15  {'NNP': 14.285714285714285, 'VBZ': 14.28571428...
# 16  {'DT': 20.0, 'NN': 33.33333333333333, 'IN': 20...
# 17  {'IN': 21.428571428571427, 'DT': 14.2857142857...
# 18  {'NNP': 6.25, 'VBZ': 18.75, 'RB': 12.5, 'JJ': ...
# 19  {'DT': 7.142857142857142, 'JJ': 7.142857142857...
# 20  {'CD': 7.142857142857142, 'NNS': 7.14285714285...
# 21  {'NNS': 6.25, 'VBP': 4.6875, 'VBN': 3.125, 'IN...
# 22  {'DT': 10.612244897959183, 'JJ': 7.34693877551...
#
#                                               2-grams  \
# 0   [(DT, JJ), (JJ, NN), (NN, NN), (NN, VBZ), (VBZ...
# 1                 [(NNP, NNP), (NNP, NNP), (NNP, NN)]
# 2   [(DT, JJ), (JJ, JJ), (JJ, NN), (NN, NNS), (NNS...
# 3   [(JJ, NN), (NN, VBZ), (VBZ, VBG), (VBG, DT), (...
# 4   [(VBG, NNS), (NNS, VBP), (VBP, JJ), (JJ, IN), ...
# 5   [(NNP, NN), (NN, VBZ), (VBZ, DT), (DT, JJ), (J...
# 6   [(PRP, VBP), (VBP, RB), (RB, JJ), (JJ, NNS), (...
# 7   [(DT, NN), (NN, VBZ), (VBZ, IN), (IN, DT), (DT...
# 8         [(NNP, VBZ), (VBZ, DT), (DT, JJ), (JJ, NN)]
# 9   [(NNP, JJ), (JJ, NN), (NN, VBZ), (VBZ, RB), (R...
# 10  [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, IN), (I...
# 11      [(DT, JJ), (JJ, NNS), (NNS, NNS), (NNS, VBP)]
# 12        [(NNP, VBZ), (VBZ, DT), (DT, NN), (NN, NN)]
# 13        [(VBG, NNS), (NNS, IN), (IN, DT), (DT, NN)]
# 14  [(DT, NN), (NN, VBZ), (VBZ, JJ), (JJ, CC), (CC...
# 15  [(NNP, VBZ), (VBZ, VBN), (VBN, IN), (IN, DT), ...
# 16  [(DT, NN), (NN, NN), (NN, IN), (IN, DT), (DT, ...
# 17  [(IN, DT), (DT, NN), (NN, IN), (IN, NN), (NN, ...
# 18  [(NNP, VBZ), (VBZ, RB), (RB, JJ), (JJ, NN), (N...
# 19  [(DT, JJ), (JJ, NN), (NN, TO), (TO, PRP$), (PR...
# 20  [(CD, NNS), (NNS, VBN), (VBN, IN), (IN, DT), (...
# 21  [(NNS, NNS), (NNS, VBP), (VBP, VBN), (VBN, IN)...
# 22  [(DT, JJ), (JJ, NN), (NN, WDT), (WDT, MD), (MD...
#
#                                     2-grams frequency  \
# 0   {('DT', 'JJ'): 25.0, ('JJ', 'NN'): 25.0, ('NN'...
# 1   {('NNP', 'NNP'): 66.66666666666666, ('NNP', 'N...
# 2   {('DT', 'JJ'): 12.5, ('JJ', 'JJ'): 12.5, ('JJ'...
# 3   {('JJ', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...
# 4   {('VBG', 'NNS'): 16.666666666666664, ('NNS', '...
# 5   {('NNP', 'NN'): 14.285714285714285, ('NN', 'VB...
# 6   {('PRP', 'VBP'): 12.5, ('VBP', 'RB'): 12.5, ('...
# 7   {('DT', 'NN'): 40.0, ('NN', 'VBZ'): 20.0, ('VB...
# 8   {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...
# 9   {('NNP', 'JJ'): 20.0, ('JJ', 'NN'): 20.0, ('NN...
# 10  {('NNP', 'VBZ'): 20.0, ('VBZ', 'DT'): 20.0, ('...
# 11  {('DT', 'JJ'): 25.0, ('JJ', 'NNS'): 25.0, ('NN...
# 12  {('NNP', 'VBZ'): 25.0, ('VBZ', 'DT'): 25.0, ('...
# 13  {('VBG', 'NNS'): 25.0, ('NNS', 'IN'): 25.0, ('...
# 14  {('DT', 'NN'): 20.0, ('NN', 'VBZ'): 20.0, ('VB...
# 15  {('NNP', 'VBZ'): 16.666666666666664, ('VBZ', '...
# 16  {('DT', 'NN'): 21.428571428571427, ('NN', 'NN'...
# 17  {('IN', 'DT'): 7.6923076923076925, ('DT', 'NN'...
# 18  {('NNP', 'VBZ'): 6.666666666666667, ('VBZ', 'R...
# 19  {('DT', 'JJ'): 7.6923076923076925, ('JJ', 'NN'...
# 20  {('CD', 'NNS'): 7.6923076923076925, ('NNS', 'V...
# 21  {('NNS', 'NNS'): 1.5873015873015872, ('NNS', '...
# 22  {('DT', 'JJ'): 2.8688524590163933, ('JJ', 'NN'...
#
#                                       phrases_lengths  phrase_max_length  \
# 0                                                [44]                 44
# 1                                                [20]                 20
# 2                                                [42]                 42
# 3                                                [44]                 44
# 4                                                [60]                 60
# 5                                                [53]                 53
# 6                                                [56]                 56
# 7                                                [25]                 25
# 8                                                [27]                 27
# 9                                                [36]                 36
# 10                                               [33]                 33
# 11                                               [38]                 38
# 12                                               [27]                 27
# 13                                               [30]                 30
# 14                                               [27]                 27
# 15                                               [44]                 44
# 16                                               [70]                 70
# 17                                               [73]                 73
# 18                                               [81]                 81
# 19                                               [71]                 71
# 20                                               [67]                 67
# 21                               [5, 112, 64, 85, 60]                112
# 22  [74, 66, 70, 74, 103, 35, 80, 90, 170, 27, 113...                170
#
#     phrase_min_length  phrase_avg_length      STTR
# 0                  44               44.0  0.095940
# 1                  20               20.0  0.061721
# 2                  42               42.0  0.098198
# 3                  44               44.0  0.106600
# 4                  60               60.0  0.091287
# 5                  53               53.0  0.097129
# 6                  56               56.0  0.085042
# 7                  25               25.0  0.121218
# 8                  27               27.0  0.136083
# 9                  36               36.0  0.117851
# 10                 33               33.0  0.123091
# 11                 38               38.0  0.114708
# 12                 27               27.0  0.136083
# 13                 30               30.0  0.129099
# 14                 27               27.0  0.136083
# 15                 44               44.0  0.106600
# 16                 70               70.0  0.074572
# 17                 73               73.0  0.073565
# 18                 81               81.0  0.066162
# 19                 71               71.0  0.072729
# 20                 67               67.0  0.086387
# 21                  5               65.2  0.027031
# 22                 27               88.2  0.008747
